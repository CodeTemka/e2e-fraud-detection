# %%
import os
import sys

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '../..')))

from azure_connection.ml_client_setup import ml_client
from azure.ai.ml import command, Input, Output, dsl

# %%
import uuid

job_name = f"custom_lightgbm_training_job_{uuid.uuid4().hex[:6]}"

job = command(
    name=job_name,
    description="Train a LightGBM model for fraud detection with MLflow logging and model registration",
    inputs={
        "data_path": Input(
            type="uri_file",
            path=ml_client.data.get(name="creditcard-data", version='1').path
        )
    },
    code=".",  # project root
    command="python train_script.py --data_path ${{inputs.data_path}}",
    environment="azureml://registries/azureml/environments/lightgbm-3.3/versions/69",
    compute="automated-ml-cluster",
    experiment_name="custom_train_experiment",
    display_name="Custom LightGBM Training Job"
)

# %%
returned_job = ml_client.jobs.create_or_update(job)
ml_client.jobs.stream(returned_job.name)
# Out:
# RunId: custom_lightgbm_training_job_60f836
# Web View: https://ml.azure.com/runs/custom_lightgbm_training_job_60f836?wsid=/subscriptions/aa4acb09-3611-4169-8504-1e68ad04a40f/resourcegroups/e2e-fraud-detection/workspaces/e2e-fraud-detection-ws
#
# Execution Summary
# =================
# RunId: custom_lightgbm_training_job_60f836
# Web View: https://ml.azure.com/runs/custom_lightgbm_training_job_60f836?wsid=/subscriptions/aa4acb09-3611-4169-8504-1e68ad04a40f/resourcegroups/e2e-fraud-detection/workspaces/e2e-fraud-detection-ws
#
# Warnings:
# AzureMLCompute job failed
# ExecutionFailed: [REDACTED]
# 	exit_codes: 2
# 	Appinsights Reachable: Some(true)
# ---------------------------------------------------------------------------
# JobException                              Traceback (most recent call last)
# Cell In[46], line 2
#       1 returned_job = ml_client.jobs.create_or_update(job)
# ----> 2 ml_client.jobs.stream(returned_job.name)
#
# File c:\Users\User\miniconda3\envs\azure_env\Lib\site-packages\azure\core\tracing\decorator.py:138, in distributed_trace.<locals>.decorator.<locals>.wrapper_use_tracer(*args, **kwargs)
#     136             for key, value in span_attributes.items():
#     137                 span.add_attribute(key, value)  # type: ignore
# --> 138             return func(*args, **kwargs)
#     139 else:
#     140     # Native path
#     141     config = {}
#
# File c:\Users\User\miniconda3\envs\azure_env\Lib\site-packages\azure\ai\ml\_telemetry\activity.py:288, in monitor_with_activity.<locals>.monitor.<locals>.wrapper(*args, **kwargs)
#     284     with tracer.start_as_current_span(ACTIVITY_SPAN):
#     285         with log_activity(
#     286             logger.package_logger, activity_name or f.__name__, activity_type, custom_dimensions
#     287         ):
# --> 288             return f(*args, **kwargs)
#     289 elif hasattr(logger, "package_logger"):
#     290     with log_activity(logger.package_logger, activity_name or f.__name__, activity_type, custom_dimensions):
#
# File c:\Users\User\miniconda3\envs\azure_env\Lib\site-packages\azure\ai\ml\operations\_job_operations.py:858, in JobOperations.stream(self, name)
#     855 if _is_pipeline_child_job(job_object):
#     856     raise PipelineChildJobError(job_id=job_object.id)
# --> 858 self._stream_logs_until_completion(
#     859     self._runs_operations,
#     860     job_object,
#     861     self._datastore_operations,
#     862     requests_pipeline=self._requests_pipeline,
#     863 )
#
# File c:\Users\User\miniconda3\envs\azure_env\Lib\site-packages\azure\ai\ml\operations\_job_ops_helper.py:334, in stream_logs_until_completion(run_operations, job_resource, datastore_operations, raise_exception_on_failed_job, requests_pipeline)
#     332         file_handle.write("\n")
#     333     else:
# --> 334         raise JobException(
#     335             message="Exception : \n {} ".format(json.dumps(error, indent=4)),
#     336             target=ErrorTarget.JOB,
#     337             no_personal_data_message="Exception raised on failed job.",
#     338             error_category=ErrorCategory.SYSTEM_ERROR,
#     339         )
#     341 file_handle.write("\n")
#     342 file_handle.flush()
#
# JobException: Exception :
#  {
#     "error": {
#         "code": "UserError",
#         "message": "Execution failed. User process 'python' exited with status code 2. Please check log file 'user_logs/std_log.txt' for error details. Error: usage: train_script.py [-h] --data-path DATA_PATH\ntrain_script.py: error: the following arguments are required: --data-path\n",
#         "message_parameters": {},
#         "details": []
#     },
#     "time": "0001-01-01T00:00:00.000Z",
#     "component_name": "CommonRuntime"
# }
